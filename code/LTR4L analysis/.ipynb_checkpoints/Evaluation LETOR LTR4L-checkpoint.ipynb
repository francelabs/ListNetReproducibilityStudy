# %%
import pandas as pd
import numpy as np
import os

from evaluation_tools import *
from script_maker import *
from itertools import product

# %% [markdown]
# # Evaluating LTR4L ListNet implementation

# %% [markdown]
# ## MQ2008 dataset

# %%
### GET MODELS' DETAILS

epochs=[100,500,1000]
learning_rates=[0.001,0.075]
mon=[0.01,0.1,0.3]
out_act=['Identity','Sigmoid']
hid_act= ['Identity','Sigmoid','ReLu']
number_hidden_layers = [0,1]
number_neurons = [15,46]

if 0 in number_hidden_layers:
    total_it = len(epochs)*len(learning_rates)*len(mon)*len(out_act)
    total_it += len(epochs)*len(learning_rates)*len(mon)*len(out_act)*len(hid_act)\
    *(len(number_hidden_layers)-1)*len(number_neurons)
else:
    total_it = len(epochs)*len(learning_rates)*len(mon)*len(out_act)*len(hid_act)\
    *len(number_hidden_layers)*len(number_neurons)

columns=["epochs","learning_rate","momentum","output function", "hidden function", "nb hidden layers", "nb neurons"]
dt=pd.DataFrame(columns=columns)

#No need to use hidden activation function or number of neurons per layers when there are no hidden layers
if 0 in number_hidden_layers:
    for i in product(epochs,learning_rates,mon, out_act):
        dt=dt.append(dict(zip(columns,i)),ignore_index=True)
    number_hidden_layers.remove(0)

#When there are hidden layers
for i in product(epochs,learning_rates,mon, out_act,hid_act,number_hidden_layers,number_neurons):
    dt=dt.append(dict(zip(columns,i)),ignore_index=True)

# %%
### COMPUTE THE EVALUATION SCORES
path_of_script='./script_score_MQ2008.sh'
low_bound=1
high_bound=total_it

name='ltr4l'#name that we gave to the linear models
data_fold='MQ2008'#Folder we are going to inspect... LETOR 4
set_evaluation_script(low_bound,high_bound,Folds=[1,2,3,4,5],
                      path_of_script=path_of_script,
                      data_fold=data_fold,name=name)
os.system(path_of_script)
# Out:
# 0

# %%
### GET EVALUATION SCORES

data_fold = "MQ2008"
name = "ltr4l"

metrics_df=get_summary_metrics(low_bound,high_bound,return_test=True,
                               name=name,Folds=[1,2,3,4,5],data_fold=data_fold)

# %%
### GET TRAINING TIME

data_fold = "MQ2008"
name = "ltr4l"
folds = [1,2,3,4,5]
   
duration_mean = get_training_duration(data_fold, name, folds)

# %%
### JOIN THE DATA IN ONE DATAFRAME

perf = dt.join(metrics_df, how="outer")
perf["duration_mean"] = duration_mean

# %%
perf.sort_values(['NDCG mean 1-10 vali'],ascending=False).head(10)
# Out:
#     epochs  learning_rate  momentum output function hidden function  \
# 217   1000          0.075      0.01        Identity        Identity
# 240   1000          0.075      0.30        Identity        Identity
# 216   1000          0.075      0.01        Identity        Identity
# 244   1000          0.075      0.30        Identity            ReLu
# 249   1000          0.075      0.30         Sigmoid         Sigmoid
# 220   1000          0.075      0.01        Identity            ReLu
# 224   1000          0.075      0.01         Sigmoid         Sigmoid
# 245   1000          0.075      0.30        Identity            ReLu
# 248   1000          0.075      0.30         Sigmoid         Sigmoid
# 221   1000          0.075      0.01        Identity            ReLu
#
#      nb hidden layers  nb neurons  NDCG mean 1-10 train  NDCG mean 1-10 vali  \
# 217               1.0        46.0              0.340732             0.354960
# 240               1.0        15.0              0.330410             0.341568
# 216               1.0        15.0              0.318276             0.339602
# 244               1.0        15.0              0.313248             0.334918
# 249               1.0        46.0              0.311228             0.333208
# 220               1.0        15.0              0.312436             0.332972
# 224               1.0        15.0              0.312010             0.332952
# 245               1.0        46.0              0.309676             0.332908
# 248               1.0        15.0              0.311290             0.332776
# 221               1.0        46.0              0.311672             0.332586
#
#      NDCG mean 1-10 test  Precision mean 1-10 train  Precision mean 1-10 vali  \
# 217             0.336954                   0.298068                  0.303276
# 240             0.327692                   0.290704                  0.294224
# 216             0.314006                   0.286044                  0.291220
# 244             0.311038                   0.279920                  0.285600
# 249             0.308200                   0.278242                  0.285154
# 220             0.309622                   0.279394                  0.284930
# 224             0.309194                   0.279226                  0.284762
# 245             0.307698                   0.277382                  0.284238
# 248             0.307320                   0.278246                  0.284658
# 221             0.307626                   0.278538                  0.284514
#
#      Precision mean 1-10 test  duration_mean
# 217                  0.294436        74.0088
# 240                  0.285646        30.2006
# 216                  0.279786        30.7870
# 244                  0.275162        31.3608
# 249                  0.274646        77.7736
# 220                  0.274626        28.7378
# 224                  0.274830        31.9040
# 245                  0.273614        70.9964
# 248                  0.273858        31.8820
# 221                  0.274352        76.5446

# %% [markdown]
# The results obtained by the algorithm are slightly better than the baselines provided by Microsoft

# %%
write_metrics_to_csv(low_bound,high_bound,return_test=True,
                     name=name,Folds=[1,2,3,4,5],data_fold=data_fold,
                     model_dataframe = dt)

# %% [markdown]
# ## MQ2007 dataset

# %%
### GET MODELS' DETAILS

epochs=[100,500]
learning_rates=[0.001,0.075]
mon=[0.01,0.1,0.3]
out_act=['Identity','Sigmoid']
hid_act= ['Identity','Sigmoid','ReLu']
number_hidden_layers = [0,1]
number_neurons = [15,46]

if 0 in number_hidden_layers:
    total_it = len(epochs)*len(learning_rates)*len(mon)*len(out_act)
    total_it += len(epochs)*len(learning_rates)*len(mon)*len(out_act)*len(hid_act)\
    *(len(number_hidden_layers)-1)*len(number_neurons)
else:
    total_it = len(epochs)*len(learning_rates)*len(mon)*len(out_act)*len(hid_act)\
    *len(number_hidden_layers)*len(number_neurons)

columns=["epochs","learning_rate","momentum","output function", "hidden function", "nb hidden layers", "nb neurons"]
dt=pd.DataFrame(columns=columns)

#No need to use hidden activation function or number of neurons per layers when there are no hidden layers
if 0 in number_hidden_layers:
    for i in product(epochs,learning_rates,mon, out_act):
        dt=dt.append(dict(zip(columns,i)),ignore_index=True)
    number_hidden_layers.remove(0)

#When there are hidden layers
for i in product(epochs,learning_rates,mon, out_act,hid_act,number_hidden_layers,number_neurons):
    dt=dt.append(dict(zip(columns,i)),ignore_index=True)

# %%
### COMPUTE THE EVALUATION SCORES
path_of_script='./script_score_MQ2007.sh'
low_bound=1
high_bound=total_it

name='ltr4l'#name that we gave to the linear models
data_fold='MQ2007'#Folder we are going to inspect... LETOR 4
set_evaluation_script(low_bound,high_bound,Folds=[1,2,3,4,5],
                      path_of_script=path_of_script,
                      data_fold=data_fold,name=name)
os.system(path_of_script)
# Out:
# 0

# %%
### GET EVALUATION SCORES

data_fold = "MQ2007"
name = "ltr4l"
Folds = [1,2,3,4,5]
return_test = True

metrics_df=get_summary_metrics(low_bound,high_bound,return_test=True,
                               name=name,Folds=[1,2,3,4,5],data_fold=data_fold)

# %%
### GET TRAINING TIME

data_fold = "MQ2007"
name = "ltr4l"
Folds = [1,2,3,4,5]

duration_mean = get_training_duration(data_fold, name, folds)

# %%
### JOIN THE DATA IN ONE DATAFRAME

perf = dt.join(metrics_df, how="outer")
perf["duration_mean"] = duration_mean

# %%
perf.sort_values(['NDCG mean 1-10 vali'],ascending=False).head(10)
# Out:
#     epochs  learning_rate  momentum output function hidden function  \
# 145    500          0.075      0.10        Identity        Identity
# 148    500          0.075      0.10        Identity            ReLu
# 153    500          0.075      0.10         Sigmoid         Sigmoid
# 152    500          0.075      0.10         Sigmoid         Sigmoid
# 149    500          0.075      0.10        Identity            ReLu
# 144    500          0.075      0.10        Identity        Identity
# 29     100          0.001      0.01        Identity            ReLu
# 73     100          0.075      0.10        Identity        Identity
# 97     500          0.001      0.01        Identity        Identity
# 109    500          0.001      0.10        Identity        Identity
#
#      nb hidden layers  nb neurons  NDCG mean 1-10 train  NDCG mean 1-10 vali  \
# 145               1.0        46.0              0.385580             0.391812
# 148               1.0        15.0              0.378198             0.385586
# 153               1.0        46.0              0.378202             0.382944
# 152               1.0        15.0              0.378204             0.382942
# 149               1.0        46.0              0.378202             0.382934
# 144               1.0        15.0              0.363570             0.372910
# 29                1.0        46.0              0.298004             0.289972
# 73                1.0        46.0              0.276840             0.285298
# 97                1.0        46.0              0.272748             0.273952
# 109               1.0        46.0              0.260962             0.263504
#
#      NDCG mean 1-10 test  Precision mean 1-10 train  Precision mean 1-10 vali  \
# 145             0.379550                   0.385048                  0.389122
# 148             0.374072                   0.380050                  0.385126
# 153             0.367176                   0.380436                  0.382244
# 152             0.367172                   0.380446                  0.382244
# 149             0.367176                   0.380436                  0.382238
# 144             0.360226                   0.366574                  0.371868
# 29              0.292366                   0.308868                  0.303370
# 73              0.283648                   0.290166                  0.300450
# 97              0.265756                   0.295796                  0.293654
# 109             0.263130                   0.277150                  0.281502
#
#      Precision mean 1-10 test  duration_mean
# 145                  0.381758       158.7560
# 148                  0.378714        78.8240
# 153                  0.372592       173.0262
# 152                  0.372584        71.3756
# 149                  0.372592       170.2874
# 144                  0.363414        77.3230
# 29                   0.303892       148.0128
# 73                   0.296148       561.2550
# 97                   0.289018       665.0892
# 109                  0.281716       703.9764

# %%
write_metrics_to_csv(low_bound,high_bound,return_test=True,
                     name=name,Folds=[1,2,3,4,5],data_fold=data_fold,
                     model_dataframe = dt)
