# %%
import pandas as pd
import numpy as np
import os

from evaluation_tools import *
from script_maker import *
from itertools import product

# %% [markdown]
# # Evaluating RankLib ListNet implementation

# %% [markdown]
# ## MQ2008 dataset

# %%
### GET MODELS' DETAILS

enterprise_features_path = "enterprise_features.txt"
data_fold='MQ2008'

epochs=[500,1000,1500,2000]
learning_rates=[0.001,0.00001] #there are no other options for ranklib
metrics = ['NDCG@5','NDCG@10','P@5','P@10','ERR@10']


total_it=len(epochs)*len(learning_rates)*len(metrics)

columns=["epochs","learning_rate","enterprise","Opti_method"]
dt=pd.DataFrame(columns=columns)

for i in (product(epochs,learning_rates,use_enterprise_features, metrics)):
    dt=dt.append(dict(zip(columns,i)),ignore_index=True)

# %%
path_of_script='./script_score_MQ2008.sh'
low_bound=1
high_bound=total_it

name='RankLib'#name that we gave to the linear models
data_fold='MQ2008'#Folder we are going to inspect... LETOR 4
set_evaluation_script(low_bound,high_bound,Folds=[1,2,3,4,5],
                      path_of_script=path_of_script,
                      data_fold=data_fold,name=name)
os.system(path_of_script)
# Out:
# 0

# %%
### GET EVALUATION SCORES

data_fold = "MQ2008"
name = "RankLib"

metrics_df=get_summary_metrics(low_bound,high_bound,return_test=True,
                               name=name,Folds=[1,2,3,4,5],data_fold=data_fold)

# %%
### GET TRAINING TIME

data_fold = "MQ2008"
name = "RankLib"
folds = [1,2,3,4,5]
   
duration_mean = get_training_duration(data_fold, name, folds)

# %%
### JOIN THE DATA IN ONE DATAFRAME

perf = dt.join(metrics_df, how="outer")
perf["duration_mean"] = duration_mean

# %%
perf.sort_values(['NDCG mean 1-10 vali'],ascending=False).head(10)
# Out:
#    epochs  learning_rate enterprise Opti_method  NDCG mean 1-10 train  \
# 34   1000        0.00001       True      ERR@10              0.387102
# 50   1500        0.00001       True      NDCG@5              0.388030
# 79   2000        0.00001      False      ERR@10              0.386836
# 73   2000        0.00001       True        P@10              0.382296
# 3     500        0.00100       True        P@10              0.390762
# 52   1500        0.00001       True         P@5              0.381608
# 33   1000        0.00001       True        P@10              0.385764
# 38   1000        0.00001      False        P@10              0.381334
# 44   1500        0.00100       True      ERR@10              0.385746
# 20   1000        0.00100       True      NDCG@5              0.385432
#
#     NDCG mean 1-10 vali  NDCG mean 1-10 test  Precision mean 1-10 train  \
# 34             0.386304             0.384476                   0.324782
# 50             0.385368             0.375022                   0.326054
# 79             0.385146             0.375456                   0.324920
# 73             0.385016             0.381062                   0.322382
# 3              0.384640             0.381816                   0.327752
# 52             0.384172             0.374838                   0.321876
# 33             0.383786             0.379176                   0.322878
# 38             0.383554             0.381010                   0.320068
# 44             0.383528             0.379652                   0.324566
# 20             0.383410             0.380676                   0.324028
#
#     Precision mean 1-10 vali  Precision mean 1-10 test  duration_mean
# 34                  0.325474                  0.326100         8.5290
# 50                  0.324412                  0.319540        12.8234
# 79                  0.323104                  0.321098        20.6392
# 73                  0.324428                  0.322968        16.5088
# 3                   0.324080                  0.321840         4.6276
# 52                  0.323744                  0.321248        12.7754
# 33                  0.323324                  0.321026         8.6142
# 38                  0.322398                  0.322804        10.6260
# 44                  0.322982                  0.320744        11.9592
# 20                  0.322872                  0.321164         8.3272

# %%
write_metrics_to_csv(low_bound,high_bound,return_test=True,
                     name=name,Folds=[1,2,3,4,5],data_fold=data_fold,
                     model_dataframe = dt)

# %% [markdown]
# ## MQ2007 dataset

# %%
### GET MODELS' DETAILS

enterprise_features_path = "enterprise_features.txt"
data_fold='MQ2007'

epochs=[500,1000,1500,2000]
learning_rates=[0.001,0.00001] #there are no other options for ranklib
metrics = ['NDCG@5','NDCG@10','P@5','P@10','ERR@10']


total_it=len(epochs)*len(learning_rates)*len(metrics)

columns=["epochs","learning_rate","enterprise","Opti method"]
dt=pd.DataFrame(columns=columns)

for i in (product(epochs,learning_rates,use_enterprise_features, metrics)):
    dt=dt.append(dict(zip(columns,i)),ignore_index=True)

# %%
path_of_script='./script_score_MQ2007.sh'
low_bound=1
high_bound=total_it

name='RankLib'#name that we gave to the linear models
data_fold='MQ2007'#Folder we are going to inspect... LETOR 4
set_evaluation_script(low_bound,high_bound,Folds=[1,2,3,4,5],
                      path_of_script=path_of_script,
                      data_fold=data_fold,name=name)
os.system(path_of_script)
# Out:
# 0

# %%
### GET EVALUATION SCORES

data_fold = "MQ2007"
name = "RankLib"
Folds = [1,2,3,4,5]
return_test = True

metrics_df=get_summary_metrics(low_bound,high_bound,return_test=True,
                               name=name,Folds=[1,2,3,4,5],data_fold=data_fold)

# %%
### GET TRAINING TIME

data_fold = "MQ2007"
name = "RankLib"
Folds = [1,2,3,4,5]

duration_mean = get_training_duration(data_fold, name, folds)

# %%
### JOIN THE DATA IN ONE DATAFRAME

perf = dt.join(metrics_df, how="outer")
perf["duration_mean"] = duration_mean

# %%
perf.sort_values(['NDCG mean 1-10 vali'],ascending=False).head(10)
# Out:
#    epochs  learning_rate enterprise Opti method  NDCG mean 1-10 train  \
# 43   1500        0.00100       True        P@10              0.403790
# 64   2000        0.00100       True      ERR@10              0.404402
# 62   2000        0.00100       True         P@5              0.406874
# 22   1000        0.00100       True         P@5              0.405002
# 72   2000        0.00001       True         P@5              0.403892
# 24   1000        0.00100       True      ERR@10              0.404172
# 60   2000        0.00100       True      NDCG@5              0.404162
# 68   2000        0.00100      False        P@10              0.404500
# 41   1500        0.00100       True     NDCG@10              0.401594
# 74   2000        0.00001       True      ERR@10              0.403874
#
#     NDCG mean 1-10 vali  NDCG mean 1-10 test  Precision mean 1-10 train  \
# 43             0.405234             0.405464                   0.396850
# 64             0.404924             0.405790                   0.396968
# 62             0.404610             0.408906                   0.399068
# 22             0.403792             0.404448                   0.397306
# 72             0.403738             0.402112                   0.396814
# 24             0.403348             0.401430                   0.396106
# 60             0.403264             0.403186                   0.396764
# 68             0.403196             0.402376                   0.397260
# 41             0.403150             0.404130                   0.395972
# 74             0.403030             0.403978                   0.396586
#
#     Precision mean 1-10 vali  Precision mean 1-10 test  duration_mean
# 43                  0.396970                  0.397406        63.2300
# 64                  0.396562                  0.397418        83.2440
# 62                  0.396540                  0.399292        84.8760
# 22                  0.395870                  0.396150        43.3762
# 72                  0.395930                  0.394710        85.5378
# 24                  0.395162                  0.394806        42.8580
# 60                  0.395772                  0.395794        83.4056
# 68                  0.396052                  0.395852       101.1134
# 41                  0.395466                  0.396042        63.0020
# 74                  0.395360                  0.395134        85.3480

# %%
write_metrics_to_csv(low_bound,high_bound,return_test=True,
                     name=name,Folds=[1,2,3,4,5],data_fold=data_fold,
                     model_dataframe = dt)
